# %%
import yfinance as yf
import pandas as pd
import numpy as np

df = yf.download(['601398.SS', '601939.SS'], start='2010-01-01')
df
# Out:
# /var/folders/y9/2slpdtcd62sccy809rd8q1pc0000gn/T/ipykernel_11752/79104515.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(['601398.SS', '601939.SS'], start='2010-01-01')
# [*********************100%***********************]  2 of 2 completed
# Price          Close                High                 Low            \
# Ticker     601398.SS 601939.SS 601398.SS 601939.SS 601398.SS 601939.SS
# Date
# 2010-01-04  2.318014  2.681884  2.383005  2.747617  2.318014  2.681884
# 2010-01-05  2.339678  2.721324  2.361341  2.743235  2.305016  2.664356
# 2010-01-06  2.313682  2.677502  2.339678  2.730088  2.309349  2.673120
# 2010-01-07  2.257356  2.638063  2.326679  2.695031  2.248690  2.633681
# 2010-01-08  2.266022  2.646827  2.270354  2.664356  2.244358  2.624917
# ...              ...       ...       ...       ...       ...       ...
# 2025-07-31  7.560000  9.410000  7.590000  9.420000  7.420000  9.220000
# ...

# %%
price_df = df['Close']
log_return_df = np.log(price_df / price_df.shift(1)).dropna()

# %%
log_return_df[log_return_df.index <= '2023-12-31'].corr()
# Out:
# Ticker     601398.SS  601939.SS
# Ticker
# 601398.SS   1.000000   0.837134
# 601939.SS   0.837134   1.000000
